# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("raw_combined2.csv", encoding = 'cp949', sep = ',')

# %%
df.columns
# Out:
# Index(['Company:', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17',
#        'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30'],
#       dtype='object')

# %%
skip = df.index[df.iloc[:,0].str.contains('Data', na = False)].to_list()

# %%
skip
# Out:
# [14]

# %%
df.drop(df.index[0:skip[0]+1], inplace = True)
df.drop(df.columns[0:2], axis = 1, inplace = True)

# %%
df
# Out:
#       Unnamed: 2  Unnamed: 3   Unnamed: 4    Unnamed: 5           Unnamed: 6  \
# 15        시간_1Hz   1.T_OC IN   2.T_OC OUT  3.T_BAT 상 표면  4.T_BAT 상 표면 sealed
# 16           NaN         NaN          NaN           NaN                  NaN
# 17           (s)        (°C)         (°C)          (°C)                 (°C)
# 18           NaN         NaN          NaN           NaN                  NaN
# 19      0.940537  28.1980621  28.98359655   19.60082399          19.03349355
# ...          ...         ...          ...           ...                  ...
# 10015        NaN         NaN          NaN           NaN                  NaN
# 10016        NaN         NaN          NaN           NaN                  NaN
# 10017        NaN         NaN          NaN           NaN                  NaN
# 10018        NaN         NaN          NaN           NaN                  NaN
# 10019        NaN         NaN          NaN           NaN                  NaN
#
# ...

# %%
new_header = df.iloc[0]

# %%
df.columns = new_header

# %%
df.drop(df.index[0], inplace = True)

# %%
df.drop(df.index[[0,2]], inplace = True)

# %%
ones = df.columns.str.contains("1Hz")
tens = df.columns.str.contains("10Hz")
hundreds = df.columns.str.contains("100Hz")
thousands = df.columns.str.contains("1000Hz")

# %%
print(ones.nonzero(), tens.nonzero(), hundreds.nonzero(), thousands.nonzero())
# Out:
# (array([0], dtype=int64),) (array([17], dtype=int64),) (array([], dtype=int64),) (array([], dtype=int64),)

# %%
df
# Out:
# 15       시간_1Hz   1.T_OC IN   2.T_OC OUT 3.T_BAT 상 표면 4.T_BAT 상 표면 sealed  \
# 17          (s)        (°C)         (°C)         (°C)                (°C)
# 19     0.940537  28.1980621  28.98359655  19.60082399         19.03349355
# 20     1.940537  28.1544213  28.93995575  19.51354238         18.98985275
# 21     2.940537  28.1980621  28.98359655  19.51354238         19.03349355
# 22     3.940537  28.1980621  28.98359655  19.51354238         19.03349355
# ...         ...         ...          ...          ...                 ...
# 10015       NaN         NaN          NaN          NaN                 NaN
# 10016       NaN         NaN          NaN          NaN                 NaN
# 10017       NaN         NaN          NaN          NaN                 NaN
# 10018       NaN         NaN          NaN          NaN                 NaN
# 10019       NaN         NaN          NaN          NaN                 NaN
#
# 15    5.T_BAT 상 주변공기 6.T_BAT 전 표면 7.T_BAT 전 주변공기 8.T_BAT 우 표면 9.T_BAT 우 주변공기  \
# ...

# %%
df.replace("          NOVALUE", np.nan, inplace = True)

# %%
df
# Out:
# 15       시간_1Hz   1.T_OC IN   2.T_OC OUT 3.T_BAT 상 표면 4.T_BAT 상 표면 sealed  \
# 17          (s)        (°C)         (°C)         (°C)                (°C)
# 19     0.940537  28.1980621  28.98359655  19.60082399         19.03349355
# 20     1.940537  28.1544213  28.93995575  19.51354238         18.98985275
# 21     2.940537  28.1980621  28.98359655  19.51354238         19.03349355
# 22     3.940537  28.1980621  28.98359655  19.51354238         19.03349355
# ...         ...         ...          ...          ...                 ...
# 10015       NaN         NaN          NaN          NaN                 NaN
# 10016       NaN         NaN          NaN          NaN                 NaN
# 10017       NaN         NaN          NaN          NaN                 NaN
# 10018       NaN         NaN          NaN          NaN                 NaN
# 10019       NaN         NaN          NaN          NaN                 NaN
#
# 15    5.T_BAT 상 주변공기 6.T_BAT 전 표면 7.T_BAT 전 주변공기 8.T_BAT 우 표면 9.T_BAT 우 주변공기  \
# ...

# %%
df.reindex(
# Out:
# 15       시간_1Hz   1.T_OC IN   2.T_OC OUT 3.T_BAT 상 표면 4.T_BAT 상 표면 sealed  \
# 17          (s)        (°C)         (°C)         (°C)                (°C)
# 19     0.940537  28.1980621  28.98359655  19.60082399         19.03349355
# 20     1.940537  28.1544213  28.93995575  19.51354238         18.98985275
# 21     2.940537  28.1980621  28.98359655  19.51354238         19.03349355
# 22     3.940537  28.1980621  28.98359655  19.51354238         19.03349355
# ...         ...         ...          ...          ...                 ...
# 10015       NaN         NaN          NaN          NaN                 NaN
# 10016       NaN         NaN          NaN          NaN                 NaN
# 10017       NaN         NaN          NaN          NaN                 NaN
# 10018       NaN         NaN          NaN          NaN                 NaN
# 10019       NaN         NaN          NaN          NaN                 NaN
#
# 15    5.T_BAT 상 주변공기 6.T_BAT 전 표면 7.T_BAT 전 주변공기 8.T_BAT 우 표면 9.T_BAT 우 주변공기  \
# ...
